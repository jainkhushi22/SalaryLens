# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv("D:\Glassdoor\\Data\\Cleaned_DS_Jobs.csv")
data.head()
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\G'
# <>:1: SyntaxWarning: invalid escape sequence '\G'
# C:\Users\hp\AppData\Local\Temp\ipykernel_6204\3398428442.py:1: SyntaxWarning: invalid escape sequence '\G'
#   data=pd.read_csv("D:\Glassdoor\\Data\\Cleaned_DS_Jobs.csv")
#            Job Title Salary Estimate  \
# 0  Sr Data Scientist        137-171
# 1     Data Scientist        137-171
# 2     Data Scientist        137-171
# 3     Data Scientist        137-171
# 4     Data Scientist        137-171
#
#                                      Job Description  Rating  \
# 0  Description\n\nThe Senior Data Scientist is re...     3.1
# 1  Secure our Nation, Ignite your Future\n\nJoin ...     4.2
# 2  Overview\n\n\nAnalysis Group is one of the lar...     3.8
# 3  JOB DESCRIPTION:\n\nDo you have a passion for ...     3.5
# 4  Data Scientist\nAffinity Solutions / Marketing...     2.9
#
#          Company Name       Location            Headquarters  \
# ...

# %% [markdown]
# data ki columns

# %%
data.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Type of ownership',
#        'Industry', 'Sector', 'Revenue', 'min_salary', 'max_salary',
#        'avg_salary', 'job_state', 'same_state', 'company_age', 'python',
#        'excel', 'hadoop', 'spark', 'aws', 'tableau', 'big_data', 'job_simp',
#        'seniority'],
#       dtype='object')

# %% [markdown]
# Data Cleaning

# %%
df=pd.DataFrame(data,columns=(['Job Title', 'Rating',
       'Company Name', 'Location', 'Size', 'Type of ownership',
       'Sector',  'Revenue','job_state',
       'avg_salary',  'company_age', 'python',
       'excel', 'hadoop', 'spark', 'aws', 'tableau', 'big_data', 
       'seniority']))

# %%
df.head()
# Out:
#            Job Title  Rating        Company Name       Location  \
# 0  Sr Data Scientist     3.1         Healthfirst   New York, NY
# 1     Data Scientist     4.2             ManTech  Chantilly, VA
# 2     Data Scientist     3.8      Analysis Group     Boston, MA
# 3     Data Scientist     3.5             INFICON     Newton, MA
# 4     Data Scientist     2.9  Affinity Solutions   New York, NY
#
#                       Size        Type of ownership             Sector  \
# 0   1001 to 5000 employees   Nonprofit Organization          Insurance
# 1  5001 to 10000 employees         Company - Public  Business Services
# 2   1001 to 5000 employees  Private Practice / Firm  Business Services
# 3    501 to 1000 employees         Company - Public      Manufacturing
# 4      51 to 200 employees        Company - Private  Business Services
#
#                       Revenue job_state  avg_salary  company_age  python  \
# 0    Unknown / Non-Applicable        NY         154           27       0
# ...

# %% [markdown]
# finding unique values in columns

# %%
np.unique(df['seniority'].values)
# Out:
# array(['jr', 'na', 'senior'], dtype=object)

# %%
df['Revenue'].unique()
# Out:
# array(['Unknown / Non-Applicable', '$1 to $2 billion (USD)',
#        '$100 to $500 million (USD)', '$10+ billion (USD)',
#        '$2 to $5 billion (USD)', '$500 million to $1 billion (USD)',
#        '$5 to $10 billion (USD)', '$10 to $25 million (USD)',
#        '$25 to $50 million (USD)', '$50 to $100 million (USD)',
#        '$1 to $5 million (USD)', '$5 to $10 million (USD)', '-1',
#        'Less than $1 million (USD)'], dtype=object)

# %%
df['Company Name'].unique
# Out:
# <bound method Series.unique of 0               Healthfirst
# 1                   ManTech
# 2            Analysis Group
# 3                   INFICON
# 4        Affinity Solutions
#                ...
# 655                TRANZACT
# 656                    JKGT
# 657              AccessHope
# 658    ChaTeck Incorporated
# 659           1-800-Flowers
# Name: Company Name, Length: 660, dtype: object>

# %% [markdown]
# Assigning the numeric value in seniority

# %%
df['seniority']=df['seniority'].map({'jr':0, 'na':-1, 'senior':1})
df.head()
# Out:
#            Job Title  Rating        Company Name       Location  \
# 0  Sr Data Scientist     3.1         Healthfirst   New York, NY
# 1     Data Scientist     4.2             ManTech  Chantilly, VA
# 2     Data Scientist     3.8      Analysis Group     Boston, MA
# 3     Data Scientist     3.5             INFICON     Newton, MA
# 4     Data Scientist     2.9  Affinity Solutions   New York, NY
#
#                       Size        Type of ownership             Sector  \
# 0   1001 to 5000 employees   Nonprofit Organization          Insurance
# 1  5001 to 10000 employees         Company - Public  Business Services
# 2   1001 to 5000 employees  Private Practice / Firm  Business Services
# 3    501 to 1000 employees         Company - Public      Manufacturing
# 4      51 to 200 employees        Company - Private  Business Services
#
#                       Revenue job_state  avg_salary  company_age  python  \
# 0    Unknown / Non-Applicable        NY         154           27       0
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# bar plot ---seniority vs Avg salary

# %%
sns.barplot(x='seniority',y='avg_salary',data=df)
plt.title("salary trend by experience")
plt.show()

# %%
skills=['python',
       'excel', 'hadoop', 'spark', 'aws', 'tableau', 'big_data']
skill_counts=df[skills].sum().sort_values(ascending=False)
skill_counts.values
# Out:
# array([482, 291, 186, 172, 140, 136, 122], dtype=int64)

# %% [markdown]
# skill demand trend means how many jobs want which skills

# %%
sns.barplot(x=skill_counts.index,y=skill_counts.values)
plt.ylabel("Number of Jobs Requiring Skill")
plt.title("skill demand trend")
# Out:
# Text(0.5, 1.0, 'skill demand trend')

# %%
df[df['Rating']==5].shape[0] #there are 36 companies who got 5 rating
# Out:
# 36

# %%
#this is the companies data who got 5 rating
top_company=df.iloc[df['Rating'].sort_values(ascending=False).head(36).index]
top_company.head()
# Out:
#                             Job Title  Rating              Company Name  \
# 575  Senior Machine Learning Engineer     5.0                  LifeOmic
# 220                    Data Scientist     5.0                       REE
# 624  Data Scientist - TS/SCI Required     5.0  Phoenix Operations Group
# 31                     Data Scientist     5.0             Cohere Health
# 205  Data Scientist - TS/SCI Required     5.0  Phoenix Operations Group
#
#           Location                 Size  Type of ownership  \
# 575    Raleigh, NC  51 to 200 employees  Company - Private
# 220  United States  51 to 200 employees  Company - Private
# 624  Baltimore, MD    1 to 50 employees  Company - Private
# 31      Boston, MA    1 to 50 employees  Company - Private
# 205  Baltimore, MD    1 to 50 employees  Company - Private
#
#                      Sector                   Revenue job_state  avg_salary  \
# 575  Information Technology  Unknown / Non-Applicable        NC         148
# ...

# %%
data['Location'].unique
# Out:
# <bound method Series.unique of 0           New York, NY
# 1          Chantilly, VA
# 2             Boston, MA
# 3             Newton, MA
# 4           New York, NY
#              ...
# 655         Fort Lee, NJ
# 656    San Francisco, CA
# 657        Irwindale, CA
# 658    San Francisco, CA
# 659         New York, NY
# Name: Location, Length: 660, dtype: object>

# %% [markdown]
# sorting data on the basis of average salary

# %%
df1=df.iloc[df['avg_salary'].sort_values(ascending=False).head(21).index]
df1.head(3)
# Out:
#                                            Job Title  Rating  Company Name  \
# 513  Manager, Field Application Scientist, Southeast     4.2  10x Genomics
# 519                                   Data Scientist     3.5        Aptive
# 500               Real World Science, Data Scientist     4.0   AstraZeneca
#
#            Location                   Size  Type of ownership  \
# 513     Raleigh, NC  501 to 1000 employees   Company - Public
# 519  Washington, DC    51 to 200 employees  Company - Private
# 500  Wilmington, DE       10000+ employees   Company - Public
#
#                         Sector                   Revenue job_state  \
# 513  Biotech & Pharmaceuticals  Unknown / Non-Applicable        NC
# 519          Business Services  $25 to $50 million (USD)        DC
# 500  Biotech & Pharmaceuticals        $10+ billion (USD)        DE
#
#      avg_salary  company_age  python  excel  hadoop  spark  aws  tableau  \
# ...

# %%
top=df1[df1['Rating']==5]
top
 #this is the company who has given highest average salary and has 5 rating
# Out:
#                                        Job Title  Rating  \
# 502  Data Scientist(s)/Machine Learning Engineer     5.0
#
#                    Company Name      Location               Size  \
# 502  Blue Horizon Tek Solutions  New York, NY  1 to 50 employees
#
#      Type of ownership             Sector                   Revenue job_state  \
# 502  Company - Private  Business Services  Unknown / Non-Applicable        NY
#
#      avg_salary  company_age  python  excel  hadoop  spark  aws  tableau  \
# 502         271           33       1      1       0      0    0        0
#
#      big_data  seniority
# 502         0         -1

# %%
top['Company Name']
# Out:
# 502    Blue Horizon Tek Solutions
# Name: Company Name, dtype: object

# %% [markdown]
# highest average salary data in which plotting the bar plot of rating of company name

# %%
sns.barplot(x='Company Name',y='Rating',data=df1.sort_values(by='Rating',ascending=False).head(5))
plt.xticks(rotation=90)
# Out:
# ([0, 1, 2, 3, 4],
#  [Text(0, 0, 'Blue Horizon Tek Solutions'),
#   Text(1, 0, 'Klaviyo'),
#   Text(2, 0, 'Sharpedge Solutions Inc'),
#   Text(3, 0, 'Smith Hanley Associates'),
#   Text(4, 0, '10x Genomics')])

# %%
data['Sector'].unique()
# Out:
# array(['Insurance', 'Business Services', 'Manufacturing',
#        'Information Technology', 'Biotech & Pharmaceuticals', 'Retail',
#        'Oil, Gas, Energy & Utilities', 'Government', 'Health Care',
#        'Finance', 'Aerospace & Defense', '-1',
#        'Transportation & Logistics', 'Media', 'Telecommunications',
#        'Real Estate', 'Travel & Tourism', 'Agriculture & Forestry',
#        'Education', 'Accounting & Legal', 'Non-Profit',
#        'Construction, Repair & Maintenance', 'Consumer Services'],
#       dtype=object)

# %%
data['job_state'].unique()
# Out:
# array([' NY', ' VA', ' MA', ' CA', ' IL', ' MO', ' WA', ' DC', ' TN',
#        ' TX', ' PA', ' AZ', ' WI', ' GA', ' FL', 'US', ' NE', ' KS',
#        ' NH', ' NJ', ' LA', ' OH', ' IN', ' MD', ' CO', ' UT', ' OR',
#        ' MI', ' SC', ' MS', ' AL', ' RI', ' IA', ' MN', ' OK', ' CT',
#        ' NC', ' DE', ' WV'], dtype=object)

# %%
df['Job Title'].unique().shape
# Out:
# (168,)

# %%
data['job_state'].unique().shape
# Out:
# (39,)

# %% [markdown]
# take data from user that in which sector you find the data of jobs and also in which state

# %%
df['Sector'] = df['Sector'].str.strip()
df['job_state'] = df['job_state'].str.strip()

# %%
#how many jobs do you have in your sector or top companies od that sector
a = input("Enter Sector Name: ").strip()
b = input("Enter Job State: ").strip().upper()

Sector_company = df[(df['Sector'] == a) & (df['job_state'] == b)]
Sector_company
# Out:
#           Job Title  Rating                 Company Name        Location  \
# 14   Data Scientist     3.4  Mathematica Policy Research  Washington, DC
# 91   Data Scientist     3.4  Mathematica Policy Research  Washington, DC
# 364  Data Scientist     4.5      Smith Hanley Associates  Washington, DC
# 405  Data Scientist     4.1               Latitude, Inc.  Washington, DC
# 516  Data Scientist     4.5      Smith Hanley Associates  Washington, DC
# 519  Data Scientist     3.5                       Aptive  Washington, DC
#
#                        Size  Type of ownership             Sector  \
# 14   1001 to 5000 employees  Company - Private  Business Services
# 91   1001 to 5000 employees  Company - Private  Business Services
# 364       1 to 50 employees  Company - Private  Business Services
# 405       1 to 50 employees  Company - Private  Business Services
# 516       1 to 50 employees  Company - Private  Business Services
# ...

# %%
df.iloc[Sector_company['Rating'].sort_values(ascending=False).index]
# Out:
#           Job Title  Rating                 Company Name        Location  \
# 364  Data Scientist     4.5      Smith Hanley Associates  Washington, DC
# 516  Data Scientist     4.5      Smith Hanley Associates  Washington, DC
# 405  Data Scientist     4.1               Latitude, Inc.  Washington, DC
# 519  Data Scientist     3.5                       Aptive  Washington, DC
# 14   Data Scientist     3.4  Mathematica Policy Research  Washington, DC
# 91   Data Scientist     3.4  Mathematica Policy Research  Washington, DC
#
#                        Size  Type of ownership             Sector  \
# 364       1 to 50 employees  Company - Private  Business Services
# 516       1 to 50 employees  Company - Private  Business Services
# 405       1 to 50 employees  Company - Private  Business Services
# 519     51 to 200 employees  Company - Private  Business Services
# 14   1001 to 5000 employees  Company - Private  Business Services
# ...

# %%
sns.barplot(x='Company Name',y='Rating',data=Sector_company)
plt.xticks(rotation=90)
# Out:
# ([0, 1, 2, 3],
#  [Text(0, 0, 'Mathematica Policy Research'),
#   Text(1, 0, 'Smith Hanley Associates'),
#   Text(2, 0, 'Latitude, Inc.'),
#   Text(3, 0, 'Aptive')])

# %%
sns.barplot(x='Company Name',y='avg_salary',data=Sector_company)
plt.xticks(rotation=90)
# Out:
# ([0, 1, 2, 3],
#  [Text(0, 0, 'Mathematica Policy Research'),
#   Text(1, 0, 'Smith Hanley Associates'),
#   Text(2, 0, 'Latitude, Inc.'),
#   Text(3, 0, 'Aptive')])
